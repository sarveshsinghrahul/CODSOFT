# %% [markdown]
# ## ==============================================
# ## Movie Genre Classification Using TF-IDF + SVM
# ## ==============================================
#
# ## -----------------------
# ## 1. Import Libraries
# ## -----------------------

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils import resample
import numpy as np

# %% [markdown]
# ## -----------------------
# ## 2. Load Dataset
# ## -----------------------
# ## Training data has: ID, TITLE, GENRE, DESCRIPTION

# %%
train_df = pd.read_csv("train_data.txt", sep=" ::: ", engine='python', 
                       names=["ID","TITLE","GENRE","DESCRIPTION"])

# Test data has: ID, TITLE, DESCRIPTION
test_df = pd.read_csv("test_data.txt", sep=" ::: ", engine='python', 
                      names=["ID","TITLE","DESCRIPTION"])

# %% [markdown]
# ## -----------------------
# ## 3. Handle Imbalanced Classes (Optional but recommended)
# ## -----------------------
# ## Find the maximum class size

# %%
max_size = train_df['GENRE'].value_counts().max()

oversampled_list = []
for genre, group in train_df.groupby('GENRE'):
    if len(group) < max_size:
        group_upsampled = resample(group,
                                   replace=True,
                                   n_samples=max_size,
                                   random_state=42)
        oversampled_list.append(group_upsampled)
    else:
        oversampled_list.append(group)

train_df_balanced = pd.concat(oversampled_list).sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## -----------------------
# ## 4. Combine Text Features
# ## -----------------------
# ## Combine TITLE + DESCRIPTION for richer textual information

# %%
train_texts = (train_df_balanced["TITLE"] + " " + train_df_balanced["DESCRIPTION"]).values
y_train = train_df_balanced["GENRE"]
test_texts = (test_df["TITLE"] + " " + test_df["DESCRIPTION"]).values

# %% [markdown]
# ## -----------------------
# ## 5. Vectorization: TF-IDF
# ## -----------------------
# ## Convert text into numerical features

# %%
vectorizer = TfidfVectorizer(stop_words="english", max_features=30000, ngram_range=(1,3))
X_train = vectorizer.fit_transform(train_texts)
X_test = vectorizer.transform(test_texts)

# %% [markdown]
# ## -----------------------
# ## 6. Compute Class Weights
# ## -----------------------
# ## Ensures rare genres are given more importance during training

# %%
classes = np.unique(y_train)
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
class_weight_dict = dict(zip(classes, class_weights))

# %% [markdown]
# ## -----------------------
# ## 7. Train Linear SVM Classifier
# ## -----------------------

# %%
svm = LinearSVC(class_weight=class_weight_dict, max_iter=5000)
svm.fit(X_train, y_train)
# Out:
# C:\Users\sarve\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# LinearSVC(class_weight={'action': 1.0, 'adult': 1.0, 'adventure': 1.0,
#                         'animation': 1.0, 'biography': 1.0, 'comedy': 1.0,
#                         'crime': 1.0, 'documentary': 1.0, 'drama': 1.0,
#                         'family': 1.0, 'fantasy': 1.0, 'game-show': 1.0,
#                         'history': 1.0, 'horror': 1.0, 'music': 1.0,
#                         'musical': 1.0, 'mystery': 1.0, 'news': 1.0,
#                         'reality-tv': 1.0, 'romance': 1.0, 'sci-fi': 1.0,
#                         'short': 1.0, 'sport': 1.0, 'talk-show': 1.0,
#                         'thriller': 1.0, 'war': 1.0, 'western': 1.0},
#           max_iter=5000)

# %% [markdown]
# ## -----------------------
# ## 8. Predict on Test Data
# ## -----------------------

# %%
preds = svm.predict(X_test)

# %% [markdown]
# # -----------------------
# # 9. Save Predictions
# # -----------------------

# %%
output_file = "predictions.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for idx, row in test_df.iterrows():
        f.write(f"{row['ID']} ::: {row['TITLE']} ::: {preds[idx]}\n")

print(f"Predictions saved to {output_file}")
# Out:
# Predictions saved to predictions.txt

# %%
# -----------------------
# 10. Evaluate Model (if ground truth available)
# -----------------------
test_solution = pd.read_csv("test_data_solution.txt", sep=" ::: ", engine='python', 
                            names=["ID","TITLE","GENRE","DESCRIPTION"])
y_true = test_solution["GENRE"]
print("Accuracy:", accuracy_score(y_true, preds))
print(classification_report(y_true, preds))
# Out:
# Accuracy: 0.5307933579335793
#               precision    recall  f1-score   support
#
#       action       0.33      0.41      0.37      1314
#        adult       0.51      0.55      0.53       590
#    adventure       0.28      0.29      0.29       775
#    animation       0.23      0.19      0.21       498
#    biography       0.04      0.02      0.03       264
#       comedy       0.53      0.53      0.53      7446
#        crime       0.16      0.15      0.15       505
#  documentary       0.74      0.69      0.71     13096
#        drama       0.61      0.56      0.58     13612
#       family       0.20      0.22      0.21       783
#      fantasy       0.17      0.13      0.15       322
#    game-show       0.75      0.63      0.68       193
#      history       0.09      0.05      0.06       243
#       horror       0.54      0.64      0.58      2204
#        music       0.51      0.62      0.56       731
#      musical       0.18      0.12      0.14       276
#      mystery       0.15      0.08      0.11       318
#         news       0.36      0.20      0.26       181
#   reality-tv       0.31      0.37      0.33       883
#      romance       0.17      0.20      0.18       672
#       sci-fi       0.36      0.40      0.38       646
#        short       0.37      0.43      0.40      5072
#        sport       0.48      0.51      0.49       431
#    talk-show       0.41      0.37      0.39       391
#     thriller       0.22      0.28      0.25      1590
#          war       0.32      0.20      0.24       132
#      western       0.80      0.87      0.84      1032
#
#     accuracy                           0.53     54200
#    macro avg       0.36      0.36      0.36     54200
# weighted avg       0.54      0.53      0.53     54200
